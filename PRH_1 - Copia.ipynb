# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
from casadi import MX, vertcat, if_else, sqrt, integrator
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import random
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau

import optuna

# %%
# Definir a seed
seed = 42
seed2 = 42
seed3 = 42
np.random.seed(seed)

random.seed(seed)

tf.random.set_seed(seed2)

# %%
class P1Generator:
    def __init__(self, seed):
        np.random.seed(seed)
        self.generated_values = set()

    def P1(self):
        while True:
            value = np.random.uniform(4000, 5000)  # Corrigido para o intervalo desejado
            if value not in self.generated_values:
                self.generated_values.add(value)
                return value


def ale():
  return np.random.uniform(400, 500)
# Instanciando o gerador com uma seed
seed = 42  # Altere a seed conforme necessário
p1_gen = P1Generator(seed)

def Estacionario(X):
    x = X
  # Constantes
    A1 = 2.6e-3   # m²
    Lc = 2.0      # m
    alpha = 0.5   # 
    P_out = 5.0   # 
    C1 = 479.029  # Constante
    nu_P = 2.0    # m³
    K_nu = 0.38 *1000 # kg / (kBar^0.5 s)
    phi_value = 1.5   # φ
    z = 0 if x[1] < P_out else np.sqrt(x[1] - P_out)

    dmdt = (A1 / Lc) * (phi_value * 4000 - x[1])
    dPdt = ((C1**2) * (x[0] - alpha * K_nu * z)) / nu_P

    return dmdt, dPdt

stati = fsolve(Estacionario, [100000, 100000])

print(Estacionario(stati))

def Sistemas(x0, P1_value):
    x = MX.sym('x', 2)  #
    p = MX.sym('p')

    # Constantes
    A1 = 2.6e-3   # m²
    Lc = 2.0      # m
    alpha = 0.5   # 
    P_out = 5.0  # 
    C1 = 479.029  # Constante
    nu_P = 2.0    # m³
    K_nu = 0.38 *1000 # kg / (kBar^0.5 s)
    phi_value = 1.5  # φ

    z = if_else(x[1] < P_out, 0, sqrt(x[1] - P_out))

    rhs = vertcat(
        (A1 / Lc) * (phi_value * p - (x[1])),
        (C1**2) * (x[0] - alpha * K_nu * z)
    ) / nu_P

    ode = {'x': x, 'ode': rhs , 'p': p}
    F = integrator('F', 'cvodes', ode, {'tf': 90})

    #
    t_eval = np.linspace(0, 90, 120)
    sol = np.zeros((len(t_eval), 2))
    zeronum = 1e-9

    #
    for i in range(len(t_eval)):
        res = F(x0=x0, p=P1_value)
        x_next = res['xf'].full().flatten()
        sol[i] = x_next

        # Check for steady state
        if np.all(np.abs(x_next - x0) < zeronum):
            sol = sol[:i+1]
            t_eval = t_eval[:i+1]
            break

        # Update initial state
        x0 = x_next

    return sol, P1_value, t_eval

# Loop de geração de dados
def Loop(loops, stati):
    estados = []
    p1_total = []
    t_eval_total = []

    for i in range(loops):
        if i == 0:
            x0 = stati  # Inicializa com o estado estacionário
        else:
            x0 = estados[-1][-1]

        P1_v = p1_gen.P1()
        sol, P1_aleatorio, t_eval = Sistemas(x0, P1_v)
        estados.append(sol)
        p1_total.append(P1_aleatorio)

        # Tempo Total
        if i == 0:
            t_total = t_eval
        else:
            t_total = np.concatenate([t_total, t_total[-1] + t_eval])

    return estados, p1_total, t_total

aaaa, PlotP1, Plott = Loop(10, stati)
bbb = aaaa
Ploty = np.concatenate(aaaa)
M_final = Ploty[:, 0]
P_p_final = Ploty[:, 1]

# Plotar os resultados
plt.figure()
plt.plot(Plott, Ploty[:, 0], label='M (Mass Flow Rate)')
plt.xlabel('Tempo')
plt.ylabel('Valores de M')
plt.title('Soluções da ODE para M')
plt.legend()
plt.grid(True)

plt.figure()
plt.plot(Plott, Ploty[:, 1], label='P_p (Plenum Pressure)')
plt.xlabel('Tempo')
plt.ylabel('Valores de P_p')
plt.title('Soluções da ODE para P_p')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# (0.0, 0.0)

# %%
# Dados para treino
M_Ploty = np.vstack(bbb)
t_eval = np.hstack(Plott)
P1_values = np.array(PlotP1)
M = M_Ploty[:, 0]
P_p = M_Ploty[:, 1]

# Entradas e Saídas (Many to Many)
X = np.column_stack((M[:-1], P_p[:-1], np.repeat(P1_values, len(t_eval) // len(P1_values))[:len(M[:-1])]))
y = np.column_stack((M[1:], P_p[1:]))

split_index = len(X) // 2

X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Padronizar Dados
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_train = scaler_X.fit_transform(X_train)
X_test = scaler_X.transform(X_test)

y_train = scaler_y.fit_transform(y_train)
y_test = scaler_y.transform(y_test)

# %%
# Redimensionar as entradas para (batch_size, timesteps, features)
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# Função de objetivo para Optuna
def objective(trial):
    # Hiperparâmetros a serem otimizados
    n_units = trial.suggest_int('n_units', 10, 50)
    dropout_rate = trial.suggest_float('dropout_rate', 0.01, 0.5)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-2, log=True)
    
    # Construção do modelo
    model = keras.Sequential()
    model.add(layers.Bidirectional(layers.LSTM(n_units, return_sequences=False, activation='tanh'), input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(2))

    # Configuração do otimizador
    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss="mse", metrics=["mae"])

    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    
    # Treinar o modelo
    history = model.fit(X_train, y_train,
                        validation_data=(X_test, y_test),
                        epochs=50,
                        batch_size=128,
                        verbose=0,
                        callbacks=[early_stopping])
    
    # Avaliar o modelo e retornar o valor da métrica que estamos otimizando
    val_loss = model.evaluate(X_test, y_test, verbose=0)
    
    return val_loss[0]  # Queremos minimizar o val_loss

# %%
# Rodar a otimização com Optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

# Imprimir o melhor conjunto de hiperparâmetros
print(study.best_params)
# Out:
# [I 2024-10-13 00:19:15,432] A new study created in memory with name: no-name-0c8a2aa6-44c3-43d9-baec-c633618f706b
# c:\Users\fabio\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [I 2024-10-13 00:19:30,776] Trial 0 finished with value: 1.5751984119415283 and parameters: {'n_units': 19, 'dropout_rate': 0.07996695996336217, 'learning_rate': 3.3485118047092563e-05}. Best is trial 0 with value: 1.5751984119415283.
# [I 2024-10-13 00:19:44,117] Trial 1 finished with value: 1.2799651622772217 and parameters: {'n_units': 11, 'dropout_rate': 0.20852325268091196, 'learning_rate': 1.8614291383686505e-05}. Best is trial 1 with value: 1.2799651622772217.
# [I 2024-10-13 00:20:14,967] Trial 2 finished with value: 1.1803418397903442 and parameters: {'n_units': 10, 'dropout_rate': 0.1450552122895707, 'learning_rate': 6.196112992558433e-05}. Best is trial 2 with value: 1.1803418397903442.
# [I 2024-10-13 00:20:22,717] Trial 3 finished with value: 0.014477169141173363 and parameters: {'n_units': 38, 'dropout_rate': 0.3842911859343532, 'learning_rate': 0.007410292583339206}. Best is trial 3 with value: 0.014477169141173363.
# [I 2024-10-13 00:20:35,985] Trial 4 finished with value: 0.9173343777656555 and parameters: {'n_units': 15, 'dropout_rate': 0.45383712479513566, 'learning_rate': 0.00017348106565021792}. Best is trial 3 with value: 0.014477169141173363.
# [I 2024-10-13 00:20:49,352] Trial 5 finished with value: 0.01427899207919836 and parameters: {'n_units': 35, 'dropout_rate': 0.03907683623270801, 'learning_rate': 0.00046175879435273885}. Best is trial 5 with value: 0.01427899207919836.
# [I 2024-10-13 00:21:02,576] Trial 6 finished with value: 1.430393934249878 and parameters: {'n_units': 12, 'dropout_rate': 0.16444443289984767, 'learning_rate': 2.0833424313306786e-05}. Best is trial 5 with value: 0.01427899207919836.
# [I 2024-10-13 00:21:16,521] Trial 7 finished with value: 0.031420111656188965 and parameters: {'n_units': 19, 'dropout_rate': 0.4440415353218485, 'learning_rate': 0.0005337803949273791}. Best is trial 5 with value: 0.01427899207919836.
# [I 2024-10-13 00:21:25,871] Trial 8 finished with value: 0.013815476559102535 and parameters: {'n_units': 50, 'dropout_rate': 0.39178206519406417, 'learning_rate': 0.0014256038083408158}. Best is trial 8 with value: 0.013815476559102535.
# [I 2024-10-13 00:21:39,572] Trial 9 finished with value: 0.6818577647209167 and parameters: {'n_units': 17, 'dropout_rate': 0.4035345878654993, 'learning_rate': 0.00022758746013412103}. Best is trial 8 with value: 0.013815476559102535.
# [I 2024-10-13 00:21:52,453] Trial 10 finished with value: 0.0060710241086781025 and parameters: {'n_units': 50, 'dropout_rate': 0.3260617978259408, 'learning_rate': 0.0029943492316865075}. Best is trial 10 with value: 0.0060710241086781025.

# %%
X_train.shape
# Out:
# (599, 3, 1)

# %%
# Treinar o modelo final com os melhores parâmetros
best_params = study.best_params
model = keras.Sequential()
model.add(layers.Bidirectional(layers.LSTM(best_params['n_units'], return_sequences=False, activation='tanh'), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(layers.Dropout(best_params['dropout_rate']))
model.add(layers.Dense(2))

optimizer = keras.optimizers.Adam(learning_rate=best_params['learning_rate'])



model.compile(optimizer=optimizer, loss="mse", metrics=["mae"])



early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=100,
                    batch_size=128,
                    verbose=2,
                    #callbacks=[early_stopping]
                    )
# Out:
# Epoch 1/100
# c:\Users\fabio\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 5/5 - 8s - 2s/step - loss: 0.6188 - mae: 0.6635 - val_loss: 0.1083 - val_mae: 0.2813
# Epoch 2/100
# 5/5 - 0s - 33ms/step - loss: 0.0717 - mae: 0.2124 - val_loss: 0.1287 - val_mae: 0.3312
# Epoch 3/100
# 5/5 - 0s - 36ms/step - loss: 0.0622 - mae: 0.1907 - val_loss: 0.0312 - val_mae: 0.1455
# Epoch 4/100
# 5/5 - 0s - 44ms/step - loss: 0.0438 - mae: 0.1754 - val_loss: 0.0738 - val_mae: 0.2246
# Epoch 5/100
# 5/5 - 0s - 40ms/step - loss: 0.0273 - mae: 0.1252 - val_loss: 0.0088 - val_mae: 0.0612
# Epoch 6/100
# 5/5 - 0s - 37ms/step - loss: 0.0198 - mae: 0.1084 - val_loss: 0.0193 - val_mae: 0.1240
# Epoch 7/100
# 5/5 - 0s - 37ms/step - loss: 0.0140 - mae: 0.0885 - val_loss: 0.0126 - val_mae: 0.0777
# Epoch 8/100
# 5/5 - 0s - 36ms/step - loss: 0.0132 - mae: 0.0835 - val_loss: 0.0156 - val_mae: 0.0974
# Epoch 9/100
# 5/5 - 0s - 37ms/step - loss: 0.0103 - mae: 0.0710 - val_loss: 0.0066 - val_mae: 0.0584
# Epoch 10/100
# 5/5 - 0s - 37ms/step - loss: 0.0093 - mae: 0.0713 - val_loss: 0.0047 - val_mae: 0.0465
# Epoch 11/100
# 5/5 - 0s - 37ms/step - loss: 0.0074 - mae: 0.0594 - val_loss: 0.0107 - val_mae: 0.0729
# Epoch 12/100
# 5/5 - 0s - 35ms/step - loss: 0.0075 - mae: 0.0592 - val_loss: 0.0055 - val_mae: 0.0501
# Epoch 13/100
# 5/5 - 0s - 37ms/step - loss: 0.0059 - mae: 0.0536 - val_loss: 0.0043 - val_mae: 0.0487
# Epoch 14/100
# 5/5 - 0s - 37ms/step - loss: 0.0059 - mae: 0.0550 - val_loss: 0.0053 - val_mae: 0.0502
# Epoch 15/100
# 5/5 - 0s - 37ms/step - loss: 0.0052 - mae: 0.0503 - val_loss: 0.0063 - val_mae: 0.0571
# Epoch 16/100
# 5/5 - 0s - 37ms/step - loss: 0.0048 - mae: 0.0496 - val_loss: 0.0028 - val_mae: 0.0377
# Epoch 17/100
# 5/5 - 0s - 33ms/step - loss: 0.0044 - mae: 0.0487 - val_loss: 0.0051 - val_mae: 0.0549
# Epoch 18/100
# 5/5 - 0s - 34ms/step - loss: 0.0042 - mae: 0.0474 - val_loss: 0.0032 - val_mae: 0.0405
# Epoch 19/100
# 5/5 - 0s - 35ms/step - loss: 0.0040 - mae: 0.0455 - val_loss: 0.0030 - val_mae: 0.0421
# Epoch 20/100
# 5/5 - 0s - 35ms/step - loss: 0.0037 - mae: 0.0468 - val_loss: 0.0026 - val_mae: 0.0396
# Epoch 21/100
# 5/5 - 0s - 38ms/step - loss: 0.0035 - mae: 0.0448 - val_loss: 0.0043 - val_mae: 0.0481
# Epoch 22/100
# 5/5 - 0s - 34ms/step - loss: 0.0032 - mae: 0.0418 - val_loss: 0.0030 - val_mae: 0.0376
# Epoch 23/100
# 5/5 - 0s - 35ms/step - loss: 0.0030 - mae: 0.0413 - val_loss: 0.0032 - val_mae: 0.0435
# Epoch 24/100
# 5/5 - 0s - 35ms/step - loss: 0.0027 - mae: 0.0393 - val_loss: 0.0026 - val_mae: 0.0361
# Epoch 25/100
# 5/5 - 0s - 34ms/step - loss: 0.0028 - mae: 0.0393 - val_loss: 0.0026 - val_mae: 0.0399
# Epoch 26/100
# 5/5 - 0s - 38ms/step - loss: 0.0028 - mae: 0.0409 - val_loss: 0.0021 - val_mae: 0.0306
# Epoch 27/100
# 5/5 - 0s - 38ms/step - loss: 0.0024 - mae: 0.0359 - val_loss: 0.0025 - val_mae: 0.0361
# Epoch 28/100
# 5/5 - 0s - 31ms/step - loss: 0.0027 - mae: 0.0388 - val_loss: 0.0018 - val_mae: 0.0293
# Epoch 29/100
# 5/5 - 0s - 31ms/step - loss: 0.0023 - mae: 0.0349 - val_loss: 0.0020 - val_mae: 0.0308
# Epoch 30/100
# 5/5 - 0s - 44ms/step - loss: 0.0024 - mae: 0.0366 - val_loss: 0.0015 - val_mae: 0.0328
# Epoch 31/100
# 5/5 - 0s - 35ms/step - loss: 0.0025 - mae: 0.0368 - val_loss: 0.0016 - val_mae: 0.0269
# Epoch 32/100
# 5/5 - 0s - 34ms/step - loss: 0.0020 - mae: 0.0331 - val_loss: 0.0010 - val_mae: 0.0213
# Epoch 33/100
# 5/5 - 0s - 35ms/step - loss: 0.0022 - mae: 0.0340 - val_loss: 0.0019 - val_mae: 0.0302
# Epoch 34/100
# 5/5 - 0s - 31ms/step - loss: 0.0020 - mae: 0.0324 - val_loss: 8.3260e-04 - val_mae: 0.0205
# Epoch 35/100
# 5/5 - 0s - 31ms/step - loss: 0.0021 - mae: 0.0339 - val_loss: 6.9249e-04 - val_mae: 0.0202
# Epoch 36/100
# 5/5 - 0s - 35ms/step - loss: 0.0022 - mae: 0.0343 - val_loss: 8.4249e-04 - val_mae: 0.0208
# Epoch 37/100
# 5/5 - 0s - 31ms/step - loss: 0.0020 - mae: 0.0323 - val_loss: 8.1862e-04 - val_mae: 0.0180
# Epoch 38/100
# 5/5 - 0s - 35ms/step - loss: 0.0019 - mae: 0.0316 - val_loss: 7.2607e-04 - val_mae: 0.0183
# Epoch 39/100
# 5/5 - 0s - 32ms/step - loss: 0.0018 - mae: 0.0303 - val_loss: 3.5576e-04 - val_mae: 0.0142
# Epoch 40/100
# 5/5 - 0s - 38ms/step - loss: 0.0020 - mae: 0.0322 - val_loss: 3.4790e-04 - val_mae: 0.0138
# Epoch 41/100
# 5/5 - 0s - 66ms/step - loss: 0.0017 - mae: 0.0306 - val_loss: 0.0011 - val_mae: 0.0233
# Epoch 42/100
# 5/5 - 0s - 66ms/step - loss: 0.0019 - mae: 0.0323 - val_loss: 3.2465e-04 - val_mae: 0.0111
# Epoch 43/100
# 5/5 - 0s - 31ms/step - loss: 0.0017 - mae: 0.0309 - val_loss: 2.5354e-04 - val_mae: 0.0100
# Epoch 44/100
# 5/5 - 0s - 31ms/step - loss: 0.0018 - mae: 0.0302 - val_loss: 3.6292e-04 - val_mae: 0.0156
# Epoch 45/100
# 5/5 - 0s - 31ms/step - loss: 0.0017 - mae: 0.0305 - val_loss: 4.2712e-04 - val_mae: 0.0153
# Epoch 46/100
# 5/5 - 0s - 31ms/step - loss: 0.0016 - mae: 0.0286 - val_loss: 2.1242e-04 - val_mae: 0.0092
# Epoch 47/100
# 5/5 - 0s - 35ms/step - loss: 0.0015 - mae: 0.0289 - val_loss: 3.7529e-04 - val_mae: 0.0124
# Epoch 48/100
# 5/5 - 0s - 35ms/step - loss: 0.0017 - mae: 0.0301 - val_loss: 2.5423e-04 - val_mae: 0.0134
# Epoch 49/100
# 5/5 - 0s - 35ms/step - loss: 0.0018 - mae: 0.0303 - val_loss: 2.8178e-04 - val_mae: 0.0110
# Epoch 50/100
# 5/5 - 0s - 35ms/step - loss: 0.0014 - mae: 0.0278 - val_loss: 2.0411e-04 - val_mae: 0.0098
# Epoch 51/100
# 5/5 - 0s - 34ms/step - loss: 0.0018 - mae: 0.0302 - val_loss: 1.8807e-04 - val_mae: 0.0098
# Epoch 52/100
# 5/5 - 0s - 30ms/step - loss: 0.0016 - mae: 0.0298 - val_loss: 6.3051e-04 - val_mae: 0.0216
# Epoch 53/100
# 5/5 - 0s - 31ms/step - loss: 0.0018 - mae: 0.0315 - val_loss: 5.5706e-04 - val_mae: 0.0173
# Epoch 54/100
# 5/5 - 0s - 32ms/step - loss: 0.0017 - mae: 0.0287 - val_loss: 5.5486e-04 - val_mae: 0.0174
# Epoch 55/100
# 5/5 - 0s - 31ms/step - loss: 0.0017 - mae: 0.0310 - val_loss: 3.6303e-04 - val_mae: 0.0157
# Epoch 56/100
# 5/5 - 0s - 31ms/step - loss: 0.0016 - mae: 0.0289 - val_loss: 2.2032e-04 - val_mae: 0.0117
# Epoch 57/100
# 5/5 - 0s - 31ms/step - loss: 0.0016 - mae: 0.0289 - val_loss: 3.5385e-04 - val_mae: 0.0155
# Epoch 58/100
# 5/5 - 0s - 31ms/step - loss: 0.0014 - mae: 0.0275 - val_loss: 2.3456e-04 - val_mae: 0.0125
# Epoch 59/100
# 5/5 - 0s - 32ms/step - loss: 0.0015 - mae: 0.0279 - val_loss: 2.0158e-04 - val_mae: 0.0102
# Epoch 60/100
# 5/5 - 0s - 31ms/step - loss: 0.0018 - mae: 0.0301 - val_loss: 9.8803e-05 - val_mae: 0.0061
# Epoch 61/100
# 5/5 - 0s - 31ms/step - loss: 0.0014 - mae: 0.0271 - val_loss: 5.3123e-04 - val_mae: 0.0189
# Epoch 62/100
# 5/5 - 0s - 32ms/step - loss: 0.0014 - mae: 0.0273 - val_loss: 2.8304e-04 - val_mae: 0.0141
# Epoch 63/100
# 5/5 - 0s - 31ms/step - loss: 0.0015 - mae: 0.0285 - val_loss: 2.8044e-04 - val_mae: 0.0139
# Epoch 64/100
# 5/5 - 0s - 31ms/step - loss: 0.0016 - mae: 0.0293 - val_loss: 1.9013e-04 - val_mae: 0.0101
# Epoch 65/100
# 5/5 - 0s - 31ms/step - loss: 0.0014 - mae: 0.0267 - val_loss: 2.6322e-04 - val_mae: 0.0139
# Epoch 66/100
# 5/5 - 0s - 31ms/step - loss: 0.0013 - mae: 0.0270 - val_loss: 1.9179e-04 - val_mae: 0.0104
# Epoch 67/100
# 5/5 - 0s - 35ms/step - loss: 0.0013 - mae: 0.0264 - val_loss: 1.7537e-04 - val_mae: 0.0106
# Epoch 68/100
# 5/5 - 0s - 31ms/step - loss: 0.0014 - mae: 0.0274 - val_loss: 1.7400e-04 - val_mae: 0.0102
# Epoch 69/100
# 5/5 - 0s - 28ms/step - loss: 0.0013 - mae: 0.0265 - val_loss: 5.0245e-04 - val_mae: 0.0155
# Epoch 70/100
# 5/5 - 0s - 30ms/step - loss: 0.0015 - mae: 0.0280 - val_loss: 9.2523e-05 - val_mae: 0.0053
# Epoch 71/100
# 5/5 - 0s - 31ms/step - loss: 0.0015 - mae: 0.0287 - val_loss: 1.6286e-04 - val_mae: 0.0099
# Epoch 72/100
# 5/5 - 0s - 29ms/step - loss: 0.0015 - mae: 0.0286 - val_loss: 1.6349e-04 - val_mae: 0.0099
# Epoch 73/100
# 5/5 - 0s - 31ms/step - loss: 0.0014 - mae: 0.0266 - val_loss: 1.8877e-04 - val_mae: 0.0091
# Epoch 74/100
# 5/5 - 0s - 35ms/step - loss: 0.0015 - mae: 0.0276 - val_loss: 1.5211e-04 - val_mae: 0.0098
# Epoch 75/100
# 5/5 - 0s - 35ms/step - loss: 0.0014 - mae: 0.0271 - val_loss: 1.1735e-04 - val_mae: 0.0073
# Epoch 76/100
# 5/5 - 0s - 31ms/step - loss: 0.0013 - mae: 0.0257 - val_loss: 2.4483e-04 - val_mae: 0.0125
# Epoch 77/100
# 5/5 - 0s - 32ms/step - loss: 0.0013 - mae: 0.0266 - val_loss: 9.9088e-05 - val_mae: 0.0059
# Epoch 78/100
# 5/5 - 0s - 28ms/step - loss: 0.0013 - mae: 0.0253 - val_loss: 7.4211e-05 - val_mae: 0.0043
# Epoch 79/100
# 5/5 - 0s - 31ms/step - loss: 0.0014 - mae: 0.0272 - val_loss: 1.7901e-04 - val_mae: 0.0091
# Epoch 80/100
# 5/5 - 0s - 32ms/step - loss: 0.0015 - mae: 0.0280 - val_loss: 1.1702e-04 - val_mae: 0.0077
# Epoch 81/100
# 5/5 - 0s - 31ms/step - loss: 0.0012 - mae: 0.0251 - val_loss: 7.0461e-05 - val_mae: 0.0051
# Epoch 82/100
# 5/5 - 0s - 31ms/step - loss: 0.0013 - mae: 0.0256 - val_loss: 1.5653e-04 - val_mae: 0.0085
# Epoch 83/100
# 5/5 - 0s - 28ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 2.8727e-04 - val_mae: 0.0119
# Epoch 84/100
# 5/5 - 0s - 31ms/step - loss: 0.0014 - mae: 0.0279 - val_loss: 8.5467e-05 - val_mae: 0.0061
# Epoch 85/100
# 5/5 - 0s - 33ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 1.6591e-04 - val_mae: 0.0102
# Epoch 86/100
# 5/5 - 0s - 35ms/step - loss: 0.0012 - mae: 0.0259 - val_loss: 2.5728e-04 - val_mae: 0.0134
# Epoch 87/100
# 5/5 - 0s - 31ms/step - loss: 0.0013 - mae: 0.0266 - val_loss: 7.4364e-05 - val_mae: 0.0049
# Epoch 88/100
# 5/5 - 0s - 31ms/step - loss: 0.0014 - mae: 0.0272 - val_loss: 1.6045e-04 - val_mae: 0.0094
# Epoch 89/100
# 5/5 - 0s - 31ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 1.0565e-04 - val_mae: 0.0076
# Epoch 90/100
# 5/5 - 0s - 31ms/step - loss: 9.7113e-04 - mae: 0.0229 - val_loss: 5.9156e-04 - val_mae: 0.0168
# Epoch 91/100
# 5/5 - 0s - 35ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 1.2064e-04 - val_mae: 0.0085
# Epoch 92/100
# 5/5 - 0s - 35ms/step - loss: 0.0014 - mae: 0.0267 - val_loss: 2.9377e-04 - val_mae: 0.0131
# Epoch 93/100
# 5/5 - 0s - 35ms/step - loss: 0.0013 - mae: 0.0272 - val_loss: 3.2787e-04 - val_mae: 0.0161
# Epoch 94/100
# 5/5 - 0s - 30ms/step - loss: 0.0012 - mae: 0.0263 - val_loss: 1.1220e-04 - val_mae: 0.0072
# Epoch 95/100
# 5/5 - 0s - 35ms/step - loss: 0.0013 - mae: 0.0259 - val_loss: 1.0423e-04 - val_mae: 0.0066
# Epoch 96/100
# 5/5 - 0s - 35ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 1.1382e-04 - val_mae: 0.0075
# Epoch 97/100
# 5/5 - 0s - 31ms/step - loss: 0.0011 - mae: 0.0248 - val_loss: 3.2954e-04 - val_mae: 0.0149
# Epoch 98/100
# 5/5 - 0s - 32ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 1.2222e-04 - val_mae: 0.0075
# Epoch 99/100
# 5/5 - 0s - 32ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 5.0293e-05 - val_mae: 0.0028
# Epoch 100/100
# 5/5 - 0s - 31ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 1.9106e-04 - val_mae: 0.0112

# %%
# Plotar a perda de treinamento e validação
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# Inicializando as listas para armazenar as predições da rede neural
M_predicoes = []
P_p_predicoes = []

# Usar os últimos valores de M e P_p como ponto de partida
M_atual = M[-1]
P_p_atual = P_p[-1]
ultimo_P1 = p1_gen.P1()
print()
print(f"Ultimo P1: {ultimo_P1}")
print(f"Valores P1:{PlotP1}")
# Criar uma sequência de 360 pontos no intervalo de 0 a 30
t_eval = np.linspace(0, 90, 120)

# Iterar para gerar predições consecutivas correspondentes a 360 pontos
for _ in range(120):

    # Criar a entrada com o formato (M_atual, P_p_atual, ultimo_P1)
    entrada = np.array([[M_atual, P_p_atual, ultimo_P1]]) # The original error was caused because M_atual and P_p_atual were 1-D arrays
    entrada_normalizada = scaler_X.transform(entrada)

    # Realizar a predição
    predicao = model.predict(entrada_normalizada)
    predicao_original = scaler_y.inverse_transform(predicao)

    # Extrair os valores preditos para M e P_p
    M_predito = predicao_original[0, 0]
    P_p_predito = predicao_original[0, 1]
    # Armazenar as predições
    M_predicoes.append(M_predito)
    P_p_predicoes.append(P_p_predito)

    # Atualizar os valores para a próxima iteração
    M_atual = M_predito
    P_p_atual = P_p_predito

# Gerar os valores de saída da função Sistemas
sol_sistemas, _, t_eval_sistemas = Sistemas([M[-1], P_p[-1]], ultimo_P1)
M_sistemas = sol_sistemas[:, 0]
P_p_sistemas = sol_sistemas[:, 1]

# Plotar as previsões e os valores de saída da função Sistemas
plt.figure(figsize=(14, 6))

# Plotagem do M
plt.subplot(1, 2, 1)
plt.plot(t_eval, M_predicoes, label='Predições de M (Rede Neural)', color='red', linestyle='--')
plt.plot(t_eval_sistemas, M_sistemas, label='Saída de M (Sistemas)', color='blue', linestyle='-')
plt.xlabel('Tempo (s)')
plt.ylabel('Mass Flow Rate (M)')
plt.title('Comparação de predições de M')
plt.legend()
plt.grid(True)

# Plotagem do P_p
plt.subplot(1, 2, 2)
plt.plot(t_eval, P_p_predicoes, label='Predições de P_p (Rede Neural)', color='orange', linestyle='--')
plt.plot(t_eval_sistemas, P_p_sistemas, label='Saída de P_p (Sistemas)', color='green', linestyle='-')
plt.xlabel('Tempo (s)')
plt.ylabel('Plenum Pressure (P_p)')
plt.title('Comparação de predições de P_p')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Ultimo P1: 4181.824967207101
# Valores P1:[4374.5401188473625, 4950.714306409916, 4731.993941811405, 4598.658484197036, 4156.018640442437, 4155.994520336202, 4058.0836121681996, 4866.176145774935, 4601.115011743209, 4708.072577796045]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %%
# Separar os dados de entrada (X_test) e as saídas reais (y_test)
rename_X = X_test.reshape(600,3)  # Dados de entrada padronizadas (X_test)
rename_y = y_test.reshape(600,2) # Saídas reais padronizadas (y_test)

# 1. Prever os valores de saída usando o modelo treinado (predições padronizadas)
y_test_pred = model.predict(rename_X)

# 2. despadronizadas as predições (y_test_pred) e os dados reais (rename_y)
y_test_pred_desnormalized = scaler_y.inverse_transform(y_test_pred)  # Previsões despadronizadas
y_test_real_desnormalized = scaler_y.inverse_transform(rename_y)  # Saídas reais despadronizadas

# 3. Separar as colunas de saídas reais (M e P_p)
M_real = y_test_real_desnormalized[:, 0]  # Mass Flow Rate real
P_p_real = y_test_real_desnormalized[:, 1]  # Plenum Pressure real

# 4. Separar as colunas de predições (M e P_p preditos)
M_test_pred = y_test_pred_desnormalized[:, 0]  # Mass Flow Rate predito
P_p_test_pred = y_test_pred_desnormalized[:, 1]  # Plenum Pressure predito

# 5. Preparar o eixo de tempo para o teste
t_eval_test = np.linspace(0, len(M_test_pred) - 1, len(M_test_pred))

# 6. Plotando os resultados - comparações das predições com os valores reais
plt.figure(figsize=(14, 6))

# Plot para M (Mass Flow Rate)
plt.subplot(1, 2, 1)
plt.plot(t_eval_test, M_real, label='M Real (Teste)', color='blue', linestyle='-')  # Saída real de M
plt.plot(t_eval_test, M_test_pred, label='Predições de M (Teste)', color='purple', linestyle='--')  # Predições de M
plt.xlabel('Tempo (s)')
plt.ylabel('Mass Flow Rate (M)')
plt.title('Comparação entre M real e predito')
plt.legend()
plt.grid(True)

# Plot para P_p (Plenum Pressure)
plt.subplot(1, 2, 2)
plt.plot(t_eval_test, P_p_real, label='P_p Real (Teste)', color='green', linestyle='-')  # Saída real de P_p
plt.plot(t_eval_test, P_p_test_pred, label='Predições de P_p (Teste)', color='orange', linestyle='--')  # Predições de P_p
plt.xlabel('Tempo (s)')
plt.ylabel('Plenum Pressure (P_p)')
plt.title('Comparação entre P_p real e predito')
plt.legend()
plt.grid(True)

# Ajustar o layout e mostrar o gráfico
plt.tight_layout()
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
